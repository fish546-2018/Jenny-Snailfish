# %% [markdown]
# # Running Ustacks

# %% [markdown]
# This is the notebook from which I ran the script for running `ustacks` on all 44 individuals that had greater than 100,000 reads. Minimum number of reads per stack,`-m`, was set to 3 and `-p` was set to 15

# %%
! pwd
# Out:
# /media/jenny/3TB_NFTS_ext/data

# %%
! ls
# Out:
# 1078_S1_L001_R1_001.fastq     DeletedReads.md
# 1078_S1_L001_R1_001.fastq.gz  FinalPresIdeas.md
# 2to4mil.sh		      includedsamplenames.sh
# 4mil.sh			      includedsamplenames.txt
# barcodes_snailfish.txt	      possibleustacks.sh
# CappingReads.ipynb	      process_radtags.ipynb
# checksum-desktop.sha	      RunningUstacks.ipynb
# checksum-externalhd.sha       run_ustacks_jg.sh
# Data_Download_EHD.ipynb       sample1
# Data-QT-dktp.ipynb	      sampleI
# Data-QT-dktp-STACKS.ipynb

# %%
! mkdir stacks

# %%
! ls
# Out:
# 1078_S1_L001_R1_001.fastq     Data_Download_EHD.ipynb	 process_radtags.ipynb
# 1078_S1_L001_R1_001.fastq.gz  Data-QT-dktp.ipynb	 RunningUstacks.ipynb
# 2to4mil.sh		      Data-QT-dktp-STACKS.ipynb  run_ustacks_jg.sh
# 4mil.sh			      DeletedReads.md		 sample1
# barcodes_snailfish.txt	      FinalPresIdeas.md		 sampleI
# CappingReads.ipynb	      includedsamplenames.sh	 stacks
# checksum-desktop.sha	      includedsamplenames.txt
# checksum-externalhd.sha       possibleustacks.sh

# %%
# %%bash
# ustacks -h
# Out:
# ustacks 2.2
# ustacks -f file_path -i id -o path [-M max_dist] [-m min_cov] [-p num_threads]
#   f: input file path.
#   i: a unique integer ID for this sample.
#   o: output path to write results.
#   M: Maximum distance (in nucleotides) allowed between stacks (default 2).
#   m: Minimum depth of coverage required to create a stack (default 3).
#   N: Maximum distance allowed to align secondary reads to primary stacks (default: M + 2).
#   p: enable parallel execution with num_threads threads.
#   t: input file type. Supported types: fasta, fastq, gzfasta, or gzfastq (default: guess).
#   --name: a name for the sample (default: input file name minus the suffix).
#   R: retain unused reads.
#   H: disable calling haplotypes from secondary reads.
#
#   Stack assembly options:
#     d,--deleverage: enable the Deleveraging algorithm, used for resolving over merged tags.
#     --keep_high_cov: disable the algorithm that removes highly-repetitive stacks and nearby errors.
# ...

# %%
# %%bash
# bash run_ustacks_jg.sh
# Out:
# ustacks parameters selected:
#   Input file: './sampleI/include/Ebritti822-cap.fq.gz'
#   Sample ID: 1
#   Min depth of coverage to create a stack (m): 3
#   Repeat removal algorithm: enabled
#   Max distance allowed between stacks (M): 2
#   Max distance allowed to align secondary reads: 4
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: disabled
#   Gapped assembly: enabled
#   Minimum alignment length: 0.8
#   Model type: SNP
#   Alpha significance level for model: 0.05
#
# Loading RAD-Tags...1M...
#
# Loaded 2000000 reads; formed:
#   55119 stacks representing 1455122 primary reads (72.8%)
#   523843 secondary stacks representing 544878 secondary reads (27.2%)
#
# Stack coverage: mean=26.40; stdev=54.88; max=6541; n_reads=1455122(72.8%)
# Removing repetitive stacks: cov > 192 (mean+3*stdev)...
#   Blacklisted 2136 stacks.
# Coverage after repeat removal: mean=25.05; stdev=18.10; max=192; n_reads=1327202(66.4%)
#
# ...
