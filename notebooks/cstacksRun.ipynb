# %% [markdown]
# # Running cstacks

# %% [markdown]
# This the notebook I used for running cstacks to create my catalog. Done after running ustacks and stacking my reads into loci

# %%
! pwd
# Out:
# /media/jenny/3TB_NFTS_ext/data

# %%
# %%bash
# cstacks -h
# Out:
# cstacks 2.2
# cstacks -P in_dir -M popmap [-n num_mismatches] [-p num_threads]
# cstacks -s sample1_path [-s sample2_path ...] -o path [-n num_mismatches] [-p num_threads]
#
#   -P,--in_path: path to the directory containing Stacks files.
#   -M,--popmap: path to a population map file.
#   -n: number of mismatches allowed between sample loci when build the catalog (default 1; suggested: set to ustacks -M).
#   -p,--threads: enable parallel execution with num_threads threads.
#   -s: sample prefix from which to load loci into the catalog.
#   -o,--outpath: output path to write results.
#   -c,--catalog <path>: add to an existing catalog.
#
# Gapped assembly options:
#   --max_gaps: number of gaps allowed between stacks before merging (default: 2).
#   --min_aln_len: minimum length of aligned sequence in a gapped alignment (default: 0.80).
#   --disable_gapped: disable gapped alignments between stacks (default: use gapped alignments).
#
# Advanced options:
# ...

# %% [markdown]
# I kept running into issues where it would fail at sample 22. So I tried running it in pieces, but still failed.

# %% [markdown]
# `cstacks` always fails at the code after Lflorae666 when searching for gapped alignments. Try running something from after there on it's own and adding to catalog and disabling gapped alignments.

# %%
# %%bash
# cstacks -o ./stacks/ --catalog ./stacks/catalog -s ./stacks/Rattenuatu-cap -n 10 -p 15 --disable_gapped
# Out:
# cstacks parameters selected:
#   Loci matched based on sequence identity.
#   Number of mismatches allowed between stacks: 10
#   Gapped alignments: disabled
# Constructing catalog from 1 samples.
#
# Initializing existing catalog...
#   Parsing ./stacks/catalog.tags.tsv.gz
#   Parsing ./stacks/catalog.snps.tsv.gz
#   Parsing ./stacks/catalog.alleles.tsv.gz
#
# Processing sample ./stacks/Rattenuatu-cap [1 of 1]
#   Parsing ./stacks/Rattenuatu-cap.tags.tsv.gz
#   Parsing ./stacks/Rattenuatu-cap.snps.tsv.gz
#   Parsing ./stacks/Rattenuatu-cap.alleles.tsv.gz
# Searching for sequence matches...
#   293517 loci in the catalog, 4532335 kmers in the catalog hash.
# Merging matches into catalog...
#   6016 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   39130 loci were newly added to the catalog.
#   8 loci matched more than one catalog locus, linking them.
#     16 linked catalog loci were merged into 8 loci.
#
# ...

# %% [markdown]
# It worked. So now try running the whole thing with `disable_gapped`

# %%
! mkdir stacks/totcat

# %%
# %%bash
# bash run_cstacks_jg.sh
# Out:
# cstacks parameters selected:
#   Loci matched based on sequence identity.
#   Number of mismatches allowed between stacks: 10
#   Gapped alignments: disabled
# Constructing catalog from 44 samples.
#
# Initializing new catalog...
#   Parsing ./stacks/Ebritti822-cap.tags.tsv.gz
#   Parsing ./stacks/Ebritti822-cap.snps.tsv.gz
#   Parsing ./stacks/Ebritti822-cap.alleles.tsv.gz
#   41391 loci were newly added to the catalog.
#
# Processing sample ./stacks/Lferxi9829-cap [2 of 44]
#   Parsing ./stacks/Lferxi9829-cap.tags.tsv.gz
#   Parsing ./stacks/Lferxi9829-cap.snps.tsv.gz
#   Parsing ./stacks/Lferxi9829-cap.alleles.tsv.gz
# Searching for sequence matches...
#   41391 loci in the catalog, 2189003 kmers in the catalog hash.
# Merging matches into catalog...
#   2099 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   37065 loci were newly added to the catalog.
#   2 loci matched more than one catalog locus, linking them.
# ...
