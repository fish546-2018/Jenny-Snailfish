# %% [markdown]
# Notebook for attempting to execute the `denovo_map.pl` as one line of code

# %% [markdown]
# First execute with `-d` to do a dry run and doublecheck the commands to be executed

# %%
# %%bash
# denovo_map.pl --samples ./sampleI/include --popmap ./sampleI/popmap1.txt -o ./stackspl \
# -M 2 -n 10 -T 4 -d -X "ustacks: -m 5" -X "populations: -k -p 20 -r 0.5 --fasta "
# Out:
# Parsed population map: 39 files in 1 population and 1 group.
# Found 39 sample file(s).
#
# Indentifying unique stacks...
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordan521-cap.fq.gz -o ./stackspl -i 1 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordan522-cap.fq.gz -o ./stackspl -i 2 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordani86-cap.fq.gz -o ./stackspl -i 3 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordani89-cap.fq.gz -o ./stackspl -i 4 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Aungak696-cap.fq.gz -o ./stackspl -i 5 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ccandidus-cap.fq.gz -o ./stackspl -i 6 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ccfcypselur-cap.fq.gz -o ./stackspl -i 7 -M 2 -p 4  -m 5
# ...

# %% [markdown]
# All commands look good. Run command as above just without `-d` to actually execute the pipeline.

# %% [markdown]
# Virtual machine randomly shut down with no warning. Interupted run so cleared all and tried again. Second try failed because it is still having issues running `cstacks` with gapped alignments. Ammended code to add `--disable_gapped` to both `cstacks` and `sstacks`. Tried rerunning without clearing

# %%
# %%bash
# denovo_map.pl --samples ./sampleI/include --popmap ./sampleI/popmap1.txt -o ./stackspl \
# -M 2 -n 10 -T 4 -X "ustacks: -m 5" -X "cstacks: --disable_gapped" -X "sstacks: --disable_gapped" \
# -X "populations: -k -p 20 -r 0.5 --fasta "
# Out:
# Parsed population map: 39 files in 1 population and 1 group.
# Found 39 sample file(s).
#
# Indentifying unique stacks...
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordan521-cap.fq.gz -o ./stackspl -i 1 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordan522-cap.fq.gz -o ./stackspl -i 2 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordani86-cap.fq.gz -o ./stackspl -i 3 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ajordani89-cap.fq.gz -o ./stackspl -i 4 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Aungak696-cap.fq.gz -o ./stackspl -i 5 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ccandidus-cap.fq.gz -o ./stackspl -i 6 -M 2 -p 4  -m 5
#   /usr/local/bin/ustacks -t gzfastq -f ./sampleI/include/Ccfcypselur-cap.fq.gz -o ./stackspl -i 7 -M 2 -p 4  -m 5
# ...
