# %% [markdown]
# This is the notebook I used for running `sstacks` on my 22 specimens in my catalog.

# %%
# %%bash
# sstacks -h
# Out:
# sstacks 2.2
# sstacks -P dir -M popmap [-p n_threads]
# sstacks -c catalog_path -s sample_path [-s sample_path ...] -o path [-p n_threads]
#   -P,--in_path: path to the directory containing Stacks files.
#   -M,--popmap: path to a population map file from which to take sample names.
#   -s,--sample: filename prefix from which to load sample loci.
#   -c,--catalog: path to the catalog.
#   -p,--threads: enable parallel execution with num_threads threads.
#   -o,--out_path: output path to write results.
#   -x: don't verify haplotype of matching locus.
#
# Gapped assembly options:
#   --disable_gapped: disable gapped alignments between stacks (default: enable gapped alignments).

# %%
# %%bash
# sstacks -c ./stacks/ -s stacks/Lflorae666-cap -p 15 --disable_gapped
# Out:
# Searching for matches by sequence identity...
#   Parsing ./stacks/catalog.tags.tsv.gz
#   Parsing ./stacks/catalog.snps.tsv.gz
#   Parsing ./stacks/catalog.alleles.tsv.gz
# Populating kmer dictionary for exact matches...done.
#
# Processing sample 'stacks/Lflorae666-cap' [1 of 1]
#   Parsing stacks/Lflorae666-cap.tags.tsv.gz
#   Parsing stacks/Lflorae666-cap.snps.tsv.gz
#   Parsing stacks/Lflorae666-cap.alleles.tsv.gz
# Searching for sequence matches...
# 45783 sample loci compared against the catalog containing 293517 loci.
#   28678 matching loci, 8 contained no verified haplotypes.
#   8 loci matched more than one catalog locus and were excluded.
#   0 loci contained SNPs unaccounted for in the catalog and were excluded.
#   34849 total haplotypes examined from matching loci, 34812 verified.
# Outputing to file ./Lflorae666-cap.matches.tsv.gz
#
# sstacks is done.

# %%
# %%bash
# zcat ./Lflorae666-cap.matches.tsv.gz | head -n 10
# Out:
# # sstacks version 2.2; generated on 2018-12-04 08:55:53
# 272514	25	1	consensus	26	126M
# 272515	25	3	consensus	38	134M
# 272516	25	7	consensus	73	125M
# 272517	25	9	consensus	60	127M
# 272518	25	10	G	12	128M
# 272518	25	10	T	7	128M
# 1811	25	11	CCCCTCACCTCTATGGGTACTAAAGA	39	125M
# 272519	25	12	C	19	131M
# 272519	25	12	T	24	131M

# %% [markdown]
# Running into issues with gapped alignments so ran `sstacks` with `--disable_gapped` option and it worked.

# %%
! mkdir stacks/sstacks

# %%
# %%bash
# bash run_sstacks.sh
# Out:
# Searching for matches by sequence identity...
#   Parsing ./stacks/catalog.tags.tsv.gz
#   Parsing ./stacks/catalog.snps.tsv.gz
#   Parsing ./stacks/catalog.alleles.tsv.gz
# Populating kmer dictionary for exact matches...done.
#
# Processing sample './stacks/Ebritti822-cap' [1 of 44]
#   Parsing ./stacks/Ebritti822-cap.tags.tsv.gz
#   Parsing ./stacks/Ebritti822-cap.snps.tsv.gz
#   Parsing ./stacks/Ebritti822-cap.alleles.tsv.gz
# Searching for sequence matches...
# 41391 sample loci compared against the catalog containing 332639 loci.
#   32882 matching loci, 25 contained no verified haplotypes.
#   0 loci matched more than one catalog locus and were excluded.
#   25 loci contained SNPs unaccounted for in the catalog and were excluded.
#   38122 total haplotypes examined from matching loci, 38097 verified.
# Outputing to file ./Ebritti822-cap.matches.tsv.gz
#
# Processing sample './stacks/Lferxi9829-cap' [2 of 44]
#   Parsing ./stacks/Lferxi9829-cap.tags.tsv.gz
# ...
